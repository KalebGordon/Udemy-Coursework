# %%
import pandas as pd

# %%
series = pd.Series(['Red', 'Blue', 'Green'])

# %%
series
# Out:
# 0      Red
# 1     Blue
# 2    Green
# dtype: object

# %%
car_series = pd.Series(['Audi', 'BMW', 'Mercedes'])

# %%
df = pd.DataFrame({"Car Make": car_series, "Color": series})

# %%
df
# Out:
#    Car Make  Color
# 0      Audi    Red
# 1       BMW   Blue
# 2  Mercedes  Green

# %%
car_df = pd.read_csv("car-sales.csv")

# %%
car_df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_df.to_csv("Exported_car_df.csv")

# %%
car_df.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_df.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_df.info
# Out:
# <bound method DataFrame.info of      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00>

# %%
car_df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_df['Odometer (KM)'].mean()
# Out:
# 78601.4

# %%
car_df['Odometer (KM)'].sum()
# Out:
# 786014

# %%
car_df.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_df.head(5)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_df.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
car_df.tail(5)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
car_df.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
car_df.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
car_df['Odometer (KM)']
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
car_df['Odometer (KM)'].mean()
# Out:
# 78601.4

# %%
car_df[['Make', 'Doors']]
# Out:
#      Make  Doors
# 0  Toyota      4
# 1   Honda      4
# 2  Toyota      3
# 3     BMW      5
# 4  Nissan      4
# 5  Toyota      4
# 6   Honda      4
# 7   Honda      4
# 8  Toyota      4
# 9  Nissan      4

# %%
car_df.groupby(car_df['Make']).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(car_df['Odometer (KM)'])
# Out:
# (array([1., 3., 2., 1., 1., 0., 1., 0., 0., 1.]),
#  array([ 11179. ,  31370.6,  51562.2,  71753.8,  91945.4, 112137. ,
#         132328.6, 152520.2, 172711.8, 192903.4, 213095. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.plot(car_df['Price'])

# %%
car_df['Price'] = car_df['Price'].str.replace('$', '')
car_df['Price'] = car_df['Price'].str.replace(',', '')
# Out:
# c:\Users\kgmon\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.

# %%
car_df['Price'] = pd.to_numeric(car_df['Price'])

# %%
plt.plot(car_df['Price'])

# %%
car_df
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
car_df['Make'] = car_df['Make'].str.lower()

# %%
car_df
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   4000.0
# 1   honda    Red          87899      4   5000.0
# 2  toyota   Blue          32549      3   7000.0
# 3     bmw  Black          11179      5  22000.0
# 4  nissan  White         213095      4   3500.0
# 5  toyota  Green          99213      4   4500.0
# 6   honda   Blue          45698      4   7500.0
# 7   honda   Blue          54738      4   7000.0
# 8  toyota  White          60000      4   6250.0
# 9  nissan  White          31600      4   9700.0

# %%
na_car_df = pd.read_csv("car-sales-missing-data.csv")

# %%
na_car_df
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
na_car_df['Odometer'] = na_car_df['Odometer'].fillna(na_car_df['Odometer'].mean())

# %%
na_car_df
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
na_car_df.dropna(inplace=True)

# %%
na_car_df
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
na_car_df['Seats'] = 5

# %%
na_car_df
# Out:
#      Make Colour       Odometer  Doors    Price  Seats
# 0  Toyota  White  150043.000000    4.0   $4,000      5
# 1   Honda    Red   87899.000000    4.0   $5,000      5
# 2  Toyota   Blue   92302.666667    3.0   $7,000      5
# 3     BMW  Black   11179.000000    5.0  $22,000      5
# 4  Nissan  White  213095.000000    4.0   $3,500      5
# 5  Toyota  Green   92302.666667    4.0   $4,500      5

# %%
import random

# %%
na_car_df['Engine Size'] = 0

# %%
na_car_df['Engine Size'] = [round(random.uniform(1.3, 4.5), 1) for k in na_car_df['Engine Size']]

# %%
na_car_df
# Out:
#      Make Colour       Odometer  Doors    Price  Seats  Engine Size
# 0  Toyota  White  150043.000000    4.0   $4,000      5          1.4
# 1   Honda    Red   87899.000000    4.0   $5,000      5          4.5
# 2  Toyota   Blue   92302.666667    3.0   $7,000      5          1.9
# 3     BMW  Black   11179.000000    5.0  $22,000      5          4.2
# 4  Nissan  White  213095.000000    4.0   $3,500      5          2.2
# 5  Toyota  Green   92302.666667    4.0   $4,500      5          4.3

# %%
na_car_df.dtypes
# Out:
# Make            object
# Colour          object
# Odometer       float64
# Doors          float64
# Price           object
# Seats            int64
# Engine Size    float64
# dtype: object

# %%
na_car_df['Price'] = na_car_df['Price'].str.replace('$', '')
na_car_df['Price'] = na_car_df['Price'].str.replace(',', '')
na_car_df['Price'] = pd.to_numeric(na_car_df['Price'])
# Out:
# c:\Users\kgmon\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.

# %%
na_car_df['Price Per Kilometer'] = na_car_df['Price'] / na_car_df['Odometer']

# %%
na_car_df
# Out:
#      Make Colour       Odometer  Doors  Price  Seats  Engine Size  \
# 0  Toyota  White  150043.000000    4.0   4000      5          1.4
# 1   Honda    Red   87899.000000    4.0   5000      5          4.5
# 2  Toyota   Blue   92302.666667    3.0   7000      5          1.9
# 3     BMW  Black   11179.000000    5.0  22000      5          4.2
# 4  Nissan  White  213095.000000    4.0   3500      5          2.2
# 5  Toyota  Green   92302.666667    4.0   4500      5          4.3
#
#    Price Per Kilometer
# 0             0.026659
# 1             0.056883
# 2             0.075837
# 3             1.967976
# 4             0.016425
# 5             0.048753

# %%
na_car_df = na_car_df.drop(columns = 'Price Per Kilometer')
na_car_df
# Out:
#      Make Colour       Odometer  Doors  Price  Seats  Engine Size
# 0  Toyota  White  150043.000000    4.0   4000      5          1.4
# 1   Honda    Red   87899.000000    4.0   5000      5          4.5
# 2  Toyota   Blue   92302.666667    3.0   7000      5          1.9
# 3     BMW  Black   11179.000000    5.0  22000      5          4.2
# 4  Nissan  White  213095.000000    4.0   3500      5          2.2
# 5  Toyota  Green   92302.666667    4.0   4500      5          4.3

# %%
shuffled_df = na_car_df.sample(frac=1)
shuffled_df
# Out:
#      Make Colour       Odometer  Doors  Price  Seats  Engine Size
# 3     BMW  Black   11179.000000    5.0  22000      5          4.2
# 0  Toyota  White  150043.000000    4.0   4000      5          1.4
# 2  Toyota   Blue   92302.666667    3.0   7000      5          1.9
# 1   Honda    Red   87899.000000    4.0   5000      5          4.5
# 5  Toyota  Green   92302.666667    4.0   4500      5          4.3
# 4  Nissan  White  213095.000000    4.0   3500      5          2.2

# %%
shuffled_df.reset_index(inplace=True)

# %%
shuffled_df
# Out:
#    index    Make Colour       Odometer  Doors  Price  Seats  Engine Size
# 0      3     BMW  Black   11179.000000    5.0  22000      5          4.2
# 1      0  Toyota  White  150043.000000    4.0   4000      5          1.4
# 2      2  Toyota   Blue   92302.666667    3.0   7000      5          1.9
# 3      1   Honda    Red   87899.000000    4.0   5000      5          4.5
# 4      5  Toyota  Green   92302.666667    4.0   4500      5          4.3
# 5      4  Nissan  White  213095.000000    4.0   3500      5          2.2
